# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
 csv_file = "../Desktop/2016 bts airline_delay_causes 2.csv"
airline_data_df = pd.read_csv(csv_file)
airline_data_df.head()
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2016       1      AA  American Airlines Inc.     DFW
# 1  2016       1      AA  American Airlines Inc.     DTW
# 2  2016       1      AA  American Airlines Inc.     SEA
# 3  2016       1      AA  American Airlines Inc.     JFK
# 4  2016       1      AA  American Airlines Inc.     SJC
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...      11956.0     1534.0
# 1            Detroit, MI: Detroit Metro Wayne County        588.0       98.0
# 2          Seattle, WA: Seattle/Tacoma International        607.0       92.0
# 3        New York, NY: John F. Kennedy International       1595.0      335.0
# 4  San Jose, CA: Norman Y. Mineta San Jose Intern...        327.0       59.0
#
#    carrier_ct   weather_ct     ...       late_aircraft_ct  arr_cancelled  \
# 0      507.33        39.83     ...                 529.47          201.0
# ...

# %%
new_airline_data_df = airline_data_df[[' month','carrier_name','airport', 'arr_cancelled', ' arr_delay', ' carrier_delay', 'weather_delay',]].copy()
new_airline_data_df.head()
# Out:
#     month            carrier_name airport  arr_cancelled   arr_delay  \
# 0       1  American Airlines Inc.     DFW          201.0    106950.0
# 1       1  American Airlines Inc.     DTW           13.0      5170.0
# 2       1  American Airlines Inc.     SEA           12.0      4485.0
# 3       1  American Airlines Inc.     JFK          137.0     23698.0
# 4       1  American Airlines Inc.     SJC            0.0      2276.0
#
#     carrier_delay  weather_delay
# 0         50027.0         2842.0
# 1          1754.0          312.0
# 2          1857.0          198.0
# 3          9681.0         1592.0
# 4           985.0           94.0

# %%
 json_file = "../Resources/customer_location.json"
customer_location_df = pd.read_json(json_file)
customer_location_df.head()
